# %%
import sys
sys.path.append('../')

import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

from csbdeep.utils import normalize
from glob import glob
from skimage import io
from stardist.matching import matching_dataset
from stardist.models import StarDist2D
from tqdm import tqdm

from utils import save_scores_csv, show_test_images, taus

# %%
image_dir = '/storage/annajiwons/images'
merfish_dir = f'{image_dir}/merfish'

model_dir = './models'

# %%
# 8 images (20%) chosen for test
merfish_X_test_names = sorted(glob(f'{merfish_dir}/test/images/*.tif'))
merfish_X_test = [normalize(img, 1, 99.8, axis=(0, 1)) for img in list(map(io.imread, merfish_X_test_names))]
merfish_Y_test_names = sorted(glob(f'{merfish_dir}/test/masks/*.tif'))
merfish_Y_test = list(map(io.imread, merfish_Y_test_names))

# %% [markdown]
# # 5 Additional Images

# %%
# Load 5 additional images model from disk
pretrained_add5_model = StarDist2D(None, name='2D_versatile_fluo_5', basedir=model_dir)
# Out:
# Loading network weights from 'weights_best.h5'.
# Couldn't load thresholds from 'thresholds.json', using default values. (Call 'optimize_thresholds' to change that.)
# Using default values: prob_thresh=0.5, nms_thresh=0.4.

# %%
pretrained_add5_Y_pred = [pretrained_add5_model.predict_instances(x, n_tiles=pretrained_add5_model._guess_n_tiles(x), show_tile_progress=False)
              for x in tqdm(merfish_X_test)]
# Out:
# 100%|██████████| 8/8 [02:31<00:00, 18.96s/it]

# %%
pretrained_add5_Y_pred_labels = [pred[0] for pred in pretrained_add5_Y_pred]
pretrained_add5_stats = [matching_dataset(merfish_Y_test, pretrained_add5_Y_pred_labels, thresh=t, show_progress=False) for t in tqdm(taus)]
# Out:
# 100%|██████████| 9/9 [00:35<00:00,  3.90s/it]

# %%
pretrained_add5_stats
# Out:
# [DatasetMatching(criterion='iou', thresh=0.1, fp=1, tp=42, fn=1, precision=0.9767441860465116, recall=0.9767441860465116, accuracy=0.9545454545454546, f1=0.9767441860465116, n_true=43, n_pred=43, mean_true_score=0.8063162594809103, mean_matched_score=0.8255142656590273, panoptic_quality=0.8063162594809103, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.2, fp=1, tp=42, fn=1, precision=0.9767441860465116, recall=0.9767441860465116, accuracy=0.9545454545454546, f1=0.9767441860465116, n_true=43, n_pred=43, mean_true_score=0.8063162594809103, mean_matched_score=0.8255142656590273, panoptic_quality=0.8063162594809103, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.3, fp=1, tp=42, fn=1, precision=0.9767441860465116, recall=0.9767441860465116, accuracy=0.9545454545454546, f1=0.9767441860465116, n_true=43, n_pred=43, mean_true_score=0.8063162594809103, mean_matched_score=0.8255142656590273, panoptic_quality=0.8063162594809103, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.4, fp=1, tp=42, fn=1, precision=0.9767441860465116, recall=0.9767441860465116, accuracy=0.9545454545454546, f1=0.9767441860465116, n_true=43, n_pred=43, mean_true_score=0.8063162594809103, mean_matched_score=0.8255142656590273, panoptic_quality=0.8063162594809103, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.5, fp=2, tp=41, fn=2, precision=0.9534883720930233, recall=0.9534883720930233, accuracy=0.9111111111111111, f1=0.9534883720930233, n_true=43, n_pred=43, mean_true_score=0.7966960219182071, mean_matched_score=0.835559242499583, panoptic_quality=0.7966960219182071, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.6, fp=3, tp=40, fn=3, precision=0.9302325581395349, recall=0.9302325581395349, accuracy=0.8695652173913043, f1=0.9302325581395349, n_true=43, n_pred=43, mean_true_score=0.7841984376883547, mean_matched_score=0.8430133205149813, panoptic_quality=0.7841984376883547, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.7, fp=7, tp=36, fn=7, precision=0.8372093023255814, recall=0.8372093023255814, accuracy=0.72, f1=0.8372093023255814, n_true=43, n_pred=43, mean_true_score=0.7228334545869685, mean_matched_score=0.8633844040899902, panoptic_quality=0.7228334545869685, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.8, fp=12, tp=31, fn=12, precision=0.7209302325581395, recall=0.7209302325581395, accuracy=0.5636363636363636, f1=0.7209302325581395, n_true=43, n_pred=43, mean_true_score=0.6362332259735239, mean_matched_score=0.8825170553826299, panoptic_quality=0.6362332259735239, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.9, fp=29, tp=14, fn=29, precision=0.32558139534883723, recall=0.32558139534883723, accuracy=0.19444444444444445, f1=0.32558139534883723, n_true=43, n_pred=43, mean_true_score=0.2974162639604405, mean_matched_score=0.9134928107356387, panoptic_quality=0.2974162639604405, by_image=False)]

# %%
show_test_images(merfish_X_test, merfish_Y_test, pretrained_add5_Y_pred, merfish_X_test_names)

# %%
save_scores_csv(pretrained_add5_stats, '_add5')

# %%
cv.imwrite('model2.tif', pretrained_add5_Y_pred[1][0])
# Out:
# True

# %% [markdown]
# # 10 Additional Images

# %%
# Load 10 additional images model from disk
pretrained_add10_model = StarDist2D(None, name='2D_versatile_fluo_10', basedir=model_dir)
# Out:
# Loading network weights from 'weights_best.h5'.
# Couldn't load thresholds from 'thresholds.json', using default values. (Call 'optimize_thresholds' to change that.)
# Using default values: prob_thresh=0.5, nms_thresh=0.4.

# %%
pretrained_add10_Y_pred = [pretrained_add10_model.predict_instances(x, n_tiles=pretrained_add10_model._guess_n_tiles(x), show_tile_progress=False)
              for x in tqdm(merfish_X_test)]
# Out:
# 100%|██████████| 8/8 [02:52<00:00, 21.54s/it]

# %%
pretrained_add10_Y_pred_labels = [pred[0] for pred in pretrained_add10_Y_pred]
pretrained_add10_stats = [matching_dataset(merfish_Y_test, pretrained_add10_Y_pred_labels, thresh=t, show_progress=False) for t in tqdm(taus)]
# Out:
# 100%|██████████| 9/9 [01:01<00:00,  6.83s/it]

# %%
pretrained_add10_stats
# Out:
# [DatasetMatching(criterion='iou', thresh=0.1, fp=0, tp=42, fn=1, precision=1.0, recall=0.9767441860465116, accuracy=0.9767441860465116, f1=0.9882352941176471, n_true=43, n_pred=42, mean_true_score=0.8156401119025591, mean_matched_score=0.8350601145669058, panoptic_quality=0.8252358779249421, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.2, fp=0, tp=42, fn=1, precision=1.0, recall=0.9767441860465116, accuracy=0.9767441860465116, f1=0.9882352941176471, n_true=43, n_pred=42, mean_true_score=0.8156401119025591, mean_matched_score=0.8350601145669058, panoptic_quality=0.8252358779249421, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.3, fp=0, tp=42, fn=1, precision=1.0, recall=0.9767441860465116, accuracy=0.9767441860465116, f1=0.9882352941176471, n_true=43, n_pred=42, mean_true_score=0.8156401119025591, mean_matched_score=0.8350601145669058, panoptic_quality=0.8252358779249421, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.4, fp=0, tp=42, fn=1, precision=1.0, recall=0.9767441860465116, accuracy=0.9767441860465116, f1=0.9882352941176471, n_true=43, n_pred=42, mean_true_score=0.8156401119025591, mean_matched_score=0.8350601145669058, panoptic_quality=0.8252358779249421, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.5, fp=1, tp=41, fn=2, precision=0.9761904761904762, recall=0.9534883720930233, accuracy=0.9318181818181818, f1=0.9647058823529412, n_true=43, n_pred=42, mean_true_score=0.8044097455078242, mean_matched_score=0.8436492452886937, panoptic_quality=0.8138733895726221, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.6, fp=3, tp=39, fn=4, precision=0.9285714285714286, recall=0.9069767441860465, accuracy=0.8478260869565217, f1=0.9176470588235294, n_true=43, n_pred=42, mean_true_score=0.7797861347246677, mean_matched_score=0.8597641998246337, panoptic_quality=0.7889600892508404, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.7, fp=6, tp=36, fn=7, precision=0.8571428571428571, recall=0.8372093023255814, accuracy=0.7346938775510204, f1=0.8470588235294118, n_true=43, n_pred=42, mean_true_score=0.7333800533951009, mean_matched_score=0.8759817304441484, panoptic_quality=0.7420080540232786, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.8, fp=11, tp=31, fn=12, precision=0.7380952380952381, recall=0.7209302325581395, accuracy=0.5740740740740741, f1=0.7294117647058823, n_true=43, n_pred=42, mean_true_score=0.6452953370635087, mean_matched_score=0.8950870804429315, panoptic_quality=0.6528870469113147, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.9, fp=25, tp=17, fn=26, precision=0.40476190476190477, recall=0.3953488372093023, accuracy=0.25, f1=0.4, n_true=43, n_pred=42, mean_true_score=0.3656214463927952, mean_matched_score=0.9248071879347172, panoptic_quality=0.3699228751738869, by_image=False)]

# %%
show_test_images(merfish_X_test, merfish_Y_test, pretrained_add10_Y_pred, merfish_X_test_names)

# %%
save_scores_csv(pretrained_add10_stats, '_add10')

# %%
cv.imwrite('model3.tif', pretrained_add5_Y_pred[1][0])
# Out:
# True
