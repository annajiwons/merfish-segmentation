# %%
import sys
sys.path.append('../')

import matplotlib.pyplot as plt
import numpy as np

from csbdeep.utils import normalize
from glob import glob
from skimage import io
from stardist.matching import matching_dataset
from stardist.models import StarDist2D
from tqdm import tqdm

from utils import show_test_images, taus

# %%
image_dir = f'../images'
merfish_dir = f'{image_dir}/merfish'

model_dir = './models'

# %%
# 8 images (20%) chosen for test
merfish_X_test_names = sorted(glob(f'{merfish_dir}/test/images/*.tif'))
merfish_X_test = [normalize(img, 1, 99.8, axis=(0, 1)) for img in list(map(io.imread, merfish_X_test_names))]
merfish_Y_test_names = sorted(glob(f'{merfish_dir}/test/masks/*.tif'))
merfish_Y_test = list(map(io.imread, merfish_Y_test_names))

# %%
# Load from disk
auto_mask_merfish_model = StarDist2D(None, name='auto_mask_merfish_model', basedir=model_dir)
# Out:
# Loading network weights from 'weights_best.h5'.
# Couldn't load thresholds from 'thresholds.json', using default values. (Call 'optimize_thresholds' to change that.)
# Using default values: prob_thresh=0.5, nms_thresh=0.4.

# %%
merfish_Y_pred = [auto_mask_merfish_model.predict_instances(x, n_tiles=auto_mask_merfish_model._guess_n_tiles(x), show_tile_progress=False)
              for x in tqdm(merfish_X_test)]
# Out:
# 100%|██████████| 8/8 [02:19<00:00, 17.49s/it]

# %%
merfish_Y_pred_labels = [pred[0] for pred in merfish_Y_pred]
merfish_stats = [matching_dataset(merfish_Y_test, merfish_Y_pred_labels, thresh=t, show_progress=False) for t in tqdm(taus)]
# Out:
# 100%|██████████| 9/9 [00:19<00:00,  2.21s/it]

# %%
merfish_stats
# Out:
# [DatasetMatching(criterion='iou', thresh=0.1, fp=2, tp=37, fn=6, precision=0.9487179487179487, recall=0.8604651162790697, accuracy=0.8222222222222222, f1=0.9024390243902439, n_true=43, n_pred=39, mean_true_score=0.6675670120716164, mean_matched_score=0.7758211221372839, panoptic_quality=0.7001312565629147, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.2, fp=2, tp=37, fn=6, precision=0.9487179487179487, recall=0.8604651162790697, accuracy=0.8222222222222222, f1=0.9024390243902439, n_true=43, n_pred=39, mean_true_score=0.6675670120716164, mean_matched_score=0.7758211221372839, panoptic_quality=0.7001312565629147, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.3, fp=2, tp=37, fn=6, precision=0.9487179487179487, recall=0.8604651162790697, accuracy=0.8222222222222222, f1=0.9024390243902439, n_true=43, n_pred=39, mean_true_score=0.6675670120716164, mean_matched_score=0.7758211221372839, panoptic_quality=0.7001312565629147, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.4, fp=4, tp=35, fn=8, precision=0.8974358974358975, recall=0.813953488372093, accuracy=0.7446808510638298, f1=0.8536585365853658, n_true=43, n_pred=39, mean_true_score=0.6505066074494004, mean_matched_score=0.7991938320092633, panoptic_quality=0.6822386370810785, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.5, fp=7, tp=32, fn=11, precision=0.8205128205128205, recall=0.7441860465116279, accuracy=0.64, f1=0.7804878048780488, n_true=43, n_pred=39, mean_true_score=0.6183191504833027, mean_matched_score=0.8308663584619379, panoptic_quality=0.6484810602629759, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.6, fp=8, tp=31, fn=12, precision=0.7948717948717948, recall=0.7209302325581395, accuracy=0.6078431372549019, f1=0.7560975609756098, n_true=43, n_pred=39, mean_true_score=0.6053368042628331, mean_matched_score=0.8396607284936073, panoptic_quality=0.6348654288610202, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.7, fp=11, tp=28, fn=15, precision=0.717948717948718, recall=0.6511627906976745, accuracy=0.5185185185185185, f1=0.6829268292682927, n_true=43, n_pred=39, mean_true_score=0.5576703358652944, mean_matched_score=0.8564223015074164, panoptic_quality=0.5848737668831137, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.8, fp=18, tp=21, fn=22, precision=0.5384615384615384, recall=0.4883720930232558, accuracy=0.3442622950819672, f1=0.5121951219512195, n_true=43, n_pred=39, mean_true_score=0.43283122482643577, mean_matched_score=0.8862734603588923, panoptic_quality=0.45394494311065214, by_image=False),
#  DatasetMatching(criterion='iou', thresh=0.9, fp=33, tp=6, fn=37, precision=0.15384615384615385, recall=0.13953488372093023, accuracy=0.07894736842105263, f1=0.14634146341463414, n_true=43, n_pred=39, mean_true_score=0.1296713033453152, mean_matched_score=0.9293110073080925, panoptic_quality=0.13599673277679403, by_image=False)]

# %%
show_test_images(merfish_X_test, merfish_Y_test, merfish_Y_pred, merfish_X_test_names)
