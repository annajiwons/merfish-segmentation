# %%
import sys
sys.path.append('../')
sys.path.append('../splinedistm')

import matplotlib.pyplot as plt
import numpy as np

from csbdeep.utils import normalize
from glob import glob
from skimage import io
from splinedist.models import SplineDist2D
from tqdm import tqdm

from utils import show_test_images

# %%
image_dir = f'../images'
merfish_dir = f'{image_dir}/merfish'

model_dir = './models'

# %%
# 8 images (20%) chosen for test
merfish_X_test_names = sorted(glob(f'{merfish_dir}/test/images/*.tif'))
merfish_X_test = [normalize(img, 1, 99.8, axis=(0, 1)) for img in list(map(io.imread, merfish_X_test_names))]
merfish_Y_test_names = sorted(glob(f'{merfish_dir}/test/masks/*.tif'))
merfish_Y_test = list(map(io.imread, merfish_Y_test_names))

# %%
# Load from disk
auto_mask_merfish_splinedist_model = SplineDist2D(None, name='auto_mask_merfish_splinedist_model', basedir=model_dir)
# Out:
# Loading network weights from 'weights_best.h5'.
# Couldn't load thresholds from 'thresholds.json', using default values. (Call 'optimize_thresholds' to change that.)
# Using default values: prob_thresh=0.5, nms_thresh=0.4.

# %%
# TODO run again
merfish_Y_pred = [auto_mask_merfish_splinedist_model.predict_instances(x, n_tiles=auto_mask_merfish_splinedist_model._guess_n_tiles(x), show_tile_progress=False)
              for x in tqdm(merfish_X_test)]
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-8e26ebc08ab8> in <module>
#       1 # TODO run again
# ----> 2 merfish_Y_pred = [auto_mask_merfish_splinedist_model.predict_instances(x, n_tiles=auto_mask_merfish_splinedist_model._guess_n_tiles(x), show_tile_progress=False)
#       3               for x in tqdm(merfish_X_test)]
#
# <ipython-input-10-8e26ebc08ab8> in <listcomp>(.0)
#       1 # TODO run again
# ----> 2 merfish_Y_pred = [auto_mask_merfish_splinedist_model.predict_instances(x, n_tiles=auto_mask_merfish_splinedist_model._guess_n_tiles(x), show_tile_progress=False)
#       3               for x in tqdm(merfish_X_test)]
#
# ~/Developer/merfish_seg/splinedistm/splinedist/models/base.py in predict_instances(self, img, axes, normalizer, prob_thresh, nms_thresh, n_tiles, show_tile_progress, verbose, predict_kwargs, nms_kwargs, overlap_label)
#     443         _shape_inst   = tuple(s for s,a in zip(_permute_axes(img).shape, _axes_net) if a != 'C')
#     444
# --> 445         prob, dist = self.predict(img, axes=axes, normalizer=normalizer, n_tiles=n_tiles, show_tile_progress=show_tile_progress, **predict_kwargs)
#     446         return self._instances_from_prediction(_shape_inst, prob, dist, prob_thresh=prob_thresh, nms_thresh=nms_thresh, overlap_label=overlap_label, **nms_kwargs)
#     447
#
# ~/Developer/merfish_seg/splinedistm/splinedist/models/base.py in predict(self, img, axes, normalizer, n_tiles, show_tile_progress, **predict_kwargs)
#     359             for tile, s_src, s_dst in tqdm(tile_iterator(x, n_tiles, block_sizes=axes_net_div_by, n_block_overlaps=n_block_overlaps),
#     360                                            disable=(not show_tile_progress), total=np.prod(n_tiles)):
# --> 361                 prob_tile, dist_tile = predict_direct(tile)
#     362                 # account for grid
#     363                 s_src = [slice(s.start//grid_dict.get(a,1),s.stop//grid_dict.get(a,1)) for s,a in zip(s_src,axes_net)]
#
# ~/Developer/merfish_seg/splinedistm/splinedist/models/base.py in predict_direct(tile)
#     338
#     339         def predict_direct(tile):
# --> 340             prob, dist = self.keras_model.predict(tile[np.newaxis], **predict_kwargs)
#     341             return prob[0], dist[0]
#     342
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1596                         '. Consider setting it to AutoShardPolicy.DATA.')
#    1597
# -> 1598       data_handler = data_adapter.DataHandler(
#    1599           x=x,
#    1600           batch_size=batch_size,
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1098
#    1099     adapter_cls = select_data_adapter(x, y)
# -> 1100     self._adapter = adapter_cls(
#    1101         x,
#    1102         y,
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     261                **kwargs):
#     262     super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 263     x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     264     sample_weight_modes = broadcast_sample_weight_modes(
#     265         sample_weights, sample_weight_modes)
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in _process_tensorlike(inputs)
#    1014     return x
#    1015
# -> 1016   inputs = nest.map_structure(_convert_numpy_and_scipy, inputs)
#    1017   return nest.list_to_tuple(inputs)
#    1018
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in _convert_numpy_and_scipy(x)
#    1009       if issubclass(x.dtype.type, np.floating):
#    1010         dtype = backend.floatx()
# -> 1011       return ops.convert_to_tensor_v2_with_dispatch(x, dtype=dtype)
#    1012     elif scipy_sparse and scipy_sparse.issparse(x):
#    1013       return _scipy_sparse_to_sparse_tensor(x)
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1402     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#    1403   """
# -> 1404   return convert_to_tensor_v2(
#    1405       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#    1406
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1408 def convert_to_tensor_v2(value, dtype=None, dtype_hint=None, name=None):
#    1409   """Converts the given `value` to a `Tensor`."""
# -> 1410   return convert_to_tensor(
#    1411       value=value,
#    1412       dtype=dtype,
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1538
#    1539     if ret is None:
# -> 1540       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1541
#    1542     if ret is NotImplemented:
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     262     ValueError: if called on a symbolic tensor.
#     263   """
# --> 264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     265                         allow_broadcast=True)
#     266
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# ~/anaconda3/envs/merfish/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# KeyboardInterrupt:

# %%
show_test_images(merfish_X_test, merfish_Y_test, merfish_Y_pred, merfish_X_test_names)
